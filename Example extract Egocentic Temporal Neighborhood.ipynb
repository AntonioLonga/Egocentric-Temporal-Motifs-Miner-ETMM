# %%
import construction as cs
from ETN import *

# %% [markdown]
# ### Load the temporal graph as a sequence of static NetworkX graphs

# %%
data = cs.load_data("Datasets/LH10.dat")
graphs = cs.build_graphs(data,gap=19)

# %% [markdown]
# ### Count Egocentric Temporal Neighborhood
# #### K is the number of EN concatenated
# #### S is a dictionary like ETNS:count

# %%
k = 5
S = count_ETN(graphs,k)

# %%
S = {k: v for k, v in sorted(S.items(), key=lambda item: item[1], reverse=1)}

# %% [markdown]
# #### Plot the 20 most common ETN

# %%
for i in list(S.keys())[0:20]:
    print("count \t = \t",S[i])
    draw_ETN(from_ETNS_to_ETN(i,k))
# Out:
# count 	 = 	 614609
# count 	 = 	 4914
# count 	 = 	 4873
# count 	 = 	 4836
# count 	 = 	 3014
# count 	 = 	 2989
# count 	 = 	 2751
# count 	 = 	 2735
# count 	 = 	 1987
# count 	 = 	 1890
# count 	 = 	 1188
# count 	 = 	 1123
# count 	 = 	 1001
# count 	 = 	 997
# count 	 = 	 921
# count 	 = 	 905
# count 	 = 	 901
# count 	 = 	 874
# count 	 = 	 830
# count 	 = 	 530
